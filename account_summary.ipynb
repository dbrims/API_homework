# %%
import os
import plaid
import requests
import datetime
import json
from pandas.plotting import table 
import pandas as pd
import matplotlib.pyplot as plt
from dotenv import load_dotenv
# %matplotlib inline

# %%
def pretty_print_response(response):
  print(json.dumps(response, indent=4, sort_keys=True))

# %%
load_dotenv()

PLAID_CLIENT_ID = os.getenv('PLAID_CLIENT_ID')
PLAID_SBX_SECRET_KEY = os.getenv('PLAID_SBX_SECRET_KEY')
PLAID_PUBLIC_KEY = os.getenv('PLAID_PUBLIC_KEY')
PLAID_ENV = os.getenv('PLAID_ENV', 'sandbox')
PLAID_PRODUCTS = os.getenv('PLAID_PRODUCTS', 'transactions')

# %% [markdown]
# # Plaid Access Token
#
# In this section, you will use the plaid-python api to generate the correct authentication tokens to access data in the free developer Sandbox. This mimics how you might connect to your own account or a customer account, but due to privacy issues, this homework will only require connecting to and analyzing the fake data from the developer sandbox that Plaid provides.
#
# Complete the following steps to generate an access token:
# 1. Create a client to connect to plaid
# 2. Use the client to generate a public token and request the following items:
# ['transactions', 'income', 'assets']
# 3. Exchange the public token for an access token
# 4. Test the access token by requesting and printing the available test accounts

# %% [markdown]
# ### 1. Create a client to connect to plaid

# %%
INSTITUTION_ID = "ins_109508"

# %%
client = plaid.Client(client_id=PLAID_CLIENT_ID, secret=PLAID_SBX_SECRET_KEY, 
                      public_key=PLAID_PUBLIC_KEY, environment=PLAID_ENV)

# %% [markdown]
# ### 2. Generate a public token

# %%
# YOUR CODE HERE
create_tkn_response = client.Sandbox.public_token.create(INSTITUTION_ID, [PLAID_PRODUCTS])

# %% [markdown]
# ### 3. Exchange the public token for an access token

# %%
# YOUR CODE HERE
exchange_response = client.Item.public_token.exchange(create_tkn_response['public_token'])
access_token = exchange_response['access_token']

# %% [markdown]
# ### 4. Fetch Accounts

# %%
# YOUR CODE HERE
client.Accounts.get(access_token)
# Out:
# {'accounts': [{'account_id': 'zNVMRXQwJdCvARprZWJZF1rNBR4roNuoW36Bv',
#    'balances': {'available': 100,
#     'current': 110,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '0000',
#    'name': 'Plaid Checking',
#    'official_name': 'Plaid Gold Standard 0% Interest Checking',
#    'subtype': 'checking',
#    'type': 'depository'},
#   {'account_id': 'BpAl1b6KwzfJRlxeam6afpvrqk7vwrcwnzV5P',
#    'balances': {'available': 200,
#     'current': 210,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '1111',
#    'name': 'Plaid Saving',
#    'official_name': 'Plaid Silver Standard 0.1% Interest Saving',
#    'subtype': 'savings',
#    'type': 'depository'},
#   {'account_id': '33oBzApXPeHP9yJMxKaxI8eK79XedKiq3m5bA',
#    'balances': {'available': None,
#     'current': 1000,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '2222',
#    'name': 'Plaid CD',
#    'official_name': 'Plaid Bronze Standard 0.2% Interest CD',
#    'subtype': 'cd',
#    'type': 'depository'},
#   {'account_id': 'xayB9n7Wx3ilg3pKeaMeF1PjA89PQjunvyLPz',
#    'balances': {'available': None,
#     'current': 410,
#     'iso_currency_code': 'USD',
#     'limit': 2000,
#     'unofficial_currency_code': None},
#    'mask': '3333',
#    'name': 'Plaid Credit Card',
#    'official_name': 'Plaid Diamond 12.5% APR Interest Credit Card',
#    'subtype': 'credit card',
#    'type': 'credit'},
#   {'account_id': 'doBdj653gPUdMDaQrX5rf3ZeXN8ZaetZeBrzM',
#    'balances': {'available': 43200,
#     'current': 43200,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '4444',
#    'name': 'Plaid Money Market',
#    'official_name': 'Plaid Platinum Standard 1.85% Interest Money Market',
#    'subtype': 'money market',
#    'type': 'depository'},
#   {'account_id': 'a1Kd4b5rkafZky3MLrELF94EVQe4bEU7LkVJ4',
#    'balances': {'available': None,
#     'current': 320.76,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '5555',
#    'name': 'Plaid IRA',
#    'official_name': None,
#    'subtype': 'ira',
#    'type': 'investment'},
#   {'account_id': '4xDvB5ok6QFkgMnzP36PCPJ3q6ZJn3Cd7l4Vz',
#    'balances': {'available': None,
#     'current': 23631.9805,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '6666',
#    'name': 'Plaid 401k',
#    'official_name': None,
#    'subtype': '401k',
#    'type': 'investment'},
#   {'account_id': 'Nl6wmD5jqQcM3Nljp1LpCldxab8d6xiWmXkpw',
#    'balances': {'available': None,
#     'current': 65262,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '7777',
#    'name': 'Plaid Student Loan',
#    'official_name': None,
#    'subtype': 'student',
#    'type': 'loan'}],
#  'item': {'available_products': ['assets',
#    'auth',
#    'balance',
#    'credit_details',
#    'identity',
#    'income',
#    'investments',
#    'liabilities'],
#   'billed_products': ['transactions'],
#   'consent_expiration_time': None,
#   'error': None,
#   'institution_id': 'ins_109508',
#   'item_id': 'Nl6wmD5jqQcM3Nljp1LpClABKoq4W3FWAG6Vm',
#   'webhook': ''},
#  'request_id': 'KDPcWJ7RtQkaAyl'}

# %% [markdown]
# ---

# %% [markdown]
# # Account Transactions with Plaid
#
# In this section, you will use the Plaid Python SDK to connect to the Developer Sandbox account and grab a list of transactions. You will need to complete the following steps:
#
#
# 1. Use the access token to fetch the transactions for the last 90 days
# 2. Print the categories for each transaction type
# 3. Create a new DataFrame using the following fields from the JSON transaction data: `date, name, amount, category`. (For categories with more than one label, just use the first category label in the list)
# 4. Convert the data types to the appropriate types (i.e. datetimeindex for the date and float for the amount)

# %% [markdown]
# ### 1. Fetch the Transactions for the last 90 days

# %%
# YOUR CODE HERE
start_date = '{:%Y-%m-%d}'.format(datetime.datetime.now() + datetime.timedelta(-90))
end_date = '{:%Y-%m-%d}'.format(datetime.datetime.now())
transaction_response = client.Transactions.get(access_token,start_date,end_date)
print(json.dumps(transaction_response['transactions'][2],indent=4, sort_keys=True))
print(len (transaction_response['transactions']))
# Out:
# {
#     "account_id": "doBdj653gPUdMDaQrX5rf3ZeXN8ZaetZeBrzM",
#     "account_owner": null,
#     "amount": 5850,
#     "authorized_date": null,
#     "category": [
#         "Transfer",
#         "Debit"
#     ],
#     "category_id": "21006000",
#     "date": "2020-04-14",
#     "iso_currency_code": "USD",
#     "location": {
#         "address": null,
#         "city": null,
#         "country": null,
#         "lat": null,
#         "lon": null,
#         "postal_code": null,
#         "region": null,
#         "store_number": null
#     },
#     "name": "ACH Electronic CreditGUSTO PAY 123456",
#     "payment_channel": "other",
#     "payment_meta": {
#         "by_order_of": null,
#         "payee": null,
#         "payer": null,
#         "payment_method": "ACH",
#         "payment_processor": null,
#         "ppd_id": null,
#         "reason": null,
#         "reference_number": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
#     "transaction_code": null,
#     "transaction_id": "bLr3NWJzp4FjzxevPykPtwBkEg9MVKCVb8ev5",
#     "transaction_type": "special",
#     "unofficial_currency_code": null
# }
# 48

# %% [markdown]
# ### 2. Print the categories for each transaction

# %%
# YOUR CODE HERE
categories=[]
category1=[]
category2=[]
category3=[]
dates=[]
names=[]
amounts=[]

for x in range(len(transaction_response['transactions'])):
    if len(transaction_response['transactions'][x]["category"])==1:
        category1.append(transaction_response['transactions'][x]["category"][0])
        category2.append('na')
        category3.append('na')
        categories.append(f'{transaction_response["transactions"][x]["category"][0]}, na, na')
    elif len(transaction_response['transactions'][x]["category"])==2:
        category1.append(transaction_response['transactions'][x]["category"][0])
        category2.append(transaction_response['transactions'][x]["category"][1])
        category3.append('na')
        categories.append(f'{transaction_response["transactions"][x]["category"][0]}, {transaction_response["transactions"][x]["category"][1]}, na')
    elif len(transaction_response['transactions'][x]["category"])==3:
        category1.append(transaction_response['transactions'][x]["category"][0])
        category2.append(transaction_response['transactions'][x]["category"][1])
        category3.append(transaction_response['transactions'][x]["category"][2])
        categories.append(f'{transaction_response["transactions"][x]["category"][0]}, {transaction_response["transactions"][x]["category"][1]}, {transaction_response["transactions"][x]["category"][2]}')
    
    dates.append(transaction_response['transactions'][x]["date"])
    names.append(transaction_response['transactions'][x]["name"])
    amounts.append(transaction_response['transactions'][x]["amount"])
    
transactions=pd.DataFrame((list(zip(dates, names, amounts, category1, category2, category3))),
                          columns =['date','name','amount (USD)','category','sub category 1','sub category2'])
trans_cat=pd.Series(categories)
trans_cat.value_counts()  
# fig, ax = plt.subplots(1,1)
# ax.xaxis.set_visible(False) 
# ax.yaxis.set_visible(False) 
# ax.set_frame_on(False) 
# table(ax, trans_cat.value_counts() ,rowLabels=['']*trans_cat.value_counts() .shape[0],loc='center')
# fig.savefig('./output/categories.png')
# Out:
# Travel, Taxi, na                              6
# Food and Drink, Restaurants, na               6
# Food and Drink, Restaurants, Fast Food        6
# Travel, Airlines and Aviation Services, na    6
# Shops, Sporting Goods, na                     3
# Payment, na, na                               3
# Transfer, Deposit, na                         3
# Recreation, Gyms and Fitness Centers, na      3
# Payment, Credit Card, na                      3
# Food and Drink, Restaurants, Coffee Shop      3
# Transfer, Debit, na                           3
# Transfer, Credit, na                          3
# dtype: int64

# %% [markdown]
# ### 3. Create a new DataFrame using the following fields from the JSON transaction data: date, name, amount, category.
#
# (For categories with more than one label, just use the first category label in the list)

# %%
# YOUR CODE HERE
transactions=pd.DataFrame((list(zip(dates, names, amounts, category1, category2, category3))),
                          columns =['date','name','amount (USD)','category','sub category 1','sub category2'])
transactions
# Out:
#           date                                   name  amount (USD)  \
# 0   2020-04-15           CREDIT CARD 3333 PAYMENT *//         25.00
# 1   2020-04-15                                   Uber          5.40
# 2   2020-04-14  ACH Electronic CreditGUSTO PAY 123456       5850.00
# 3   2020-04-14                   CD DEPOSIT .INITIAL.       1000.00
# 4   2020-04-13                    Touchstone Climbing         78.50
# 5   2020-04-13                        United Airlines       -500.00
# 6   2020-04-12                             McDonald's         12.00
# 7   2020-04-12                              Starbucks          4.33
# 8   2020-04-11                               SparkFun         89.40
# 9   2020-04-10                           INTRST PYMNT         -4.22
# 10  2020-03-31                        United Airlines        500.00
# 11  2020-03-29                                   Uber          6.33
# 12  2020-03-26                             Tectra Inc        500.00
# 13  2020-03-25              AUTOMATIC PAYMENT - THANK       2078.50
# 14  2020-03-25                                    KFC        500.00
# 15  2020-03-25                   Madison Bicycle Shop        500.00
# 16  2020-03-16           CREDIT CARD 3333 PAYMENT *//         25.00
# 17  2020-03-16                                   Uber          5.40
# 18  2020-03-15  ACH Electronic CreditGUSTO PAY 123456       5850.00
# 19  2020-03-15                   CD DEPOSIT .INITIAL.       1000.00
# 20  2020-03-14                    Touchstone Climbing         78.50
# 21  2020-03-14                        United Airlines       -500.00
# 22  2020-03-13                             McDonald's         12.00
# 23  2020-03-13                              Starbucks          4.33
# 24  2020-03-12                               SparkFun         89.40
# 25  2020-03-11                           INTRST PYMNT         -4.22
# 26  2020-03-01                        United Airlines        500.00
# 27  2020-02-28                                   Uber          6.33
# 28  2020-02-25                             Tectra Inc        500.00
# 29  2020-02-24              AUTOMATIC PAYMENT - THANK       2078.50
# 30  2020-02-24                                    KFC        500.00
# 31  2020-02-24                   Madison Bicycle Shop        500.00
# 32  2020-02-15           CREDIT CARD 3333 PAYMENT *//         25.00
# 33  2020-02-15                                   Uber          5.40
# 34  2020-02-14  ACH Electronic CreditGUSTO PAY 123456       5850.00
# 35  2020-02-14                   CD DEPOSIT .INITIAL.       1000.00
# 36  2020-02-13                    Touchstone Climbing         78.50
# 37  2020-02-13                        United Airlines       -500.00
# 38  2020-02-12                             McDonald's         12.00
# 39  2020-02-12                              Starbucks          4.33
# 40  2020-02-11                               SparkFun         89.40
# 41  2020-02-10                           INTRST PYMNT         -4.22
# 42  2020-01-31                        United Airlines        500.00
# 43  2020-01-29                                   Uber          6.33
# 44  2020-01-26                             Tectra Inc        500.00
# 45  2020-01-25              AUTOMATIC PAYMENT - THANK       2078.50
# 46  2020-01-25                                    KFC        500.00
# 47  2020-01-25                   Madison Bicycle Shop        500.00
#
#           category                  sub category 1 sub category2
# 0          Payment                     Credit Card            na
# 1           Travel                            Taxi            na
# 2         Transfer                           Debit            na
# 3         Transfer                         Deposit            na
# 4       Recreation        Gyms and Fitness Centers            na
# 5           Travel  Airlines and Aviation Services            na
# 6   Food and Drink                     Restaurants     Fast Food
# 7   Food and Drink                     Restaurants   Coffee Shop
# 8   Food and Drink                     Restaurants            na
# 9         Transfer                          Credit            na
# 10          Travel  Airlines and Aviation Services            na
# 11          Travel                            Taxi            na
# 12  Food and Drink                     Restaurants            na
# 13         Payment                              na            na
# 14  Food and Drink                     Restaurants     Fast Food
# 15           Shops                  Sporting Goods            na
# 16         Payment                     Credit Card            na
# 17          Travel                            Taxi            na
# 18        Transfer                           Debit            na
# 19        Transfer                         Deposit            na
# 20      Recreation        Gyms and Fitness Centers            na
# 21          Travel  Airlines and Aviation Services            na
# 22  Food and Drink                     Restaurants     Fast Food
# 23  Food and Drink                     Restaurants   Coffee Shop
# 24  Food and Drink                     Restaurants            na
# 25        Transfer                          Credit            na
# 26          Travel  Airlines and Aviation Services            na
# 27          Travel                            Taxi            na
# 28  Food and Drink                     Restaurants            na
# 29         Payment                              na            na
# 30  Food and Drink                     Restaurants     Fast Food
# 31           Shops                  Sporting Goods            na
# 32         Payment                     Credit Card            na
# 33          Travel                            Taxi            na
# 34        Transfer                           Debit            na
# 35        Transfer                         Deposit            na
# 36      Recreation        Gyms and Fitness Centers            na
# 37          Travel  Airlines and Aviation Services            na
# 38  Food and Drink                     Restaurants     Fast Food
# 39  Food and Drink                     Restaurants   Coffee Shop
# 40  Food and Drink                     Restaurants            na
# 41        Transfer                          Credit            na
# 42          Travel  Airlines and Aviation Services            na
# 43          Travel                            Taxi            na
# 44  Food and Drink                     Restaurants            na
# 45         Payment                              na            na
# 46  Food and Drink                     Restaurants     Fast Food
# 47           Shops                  Sporting Goods            na

# %%
# fig, ax = plt.subplots(1,1)
# ax.xaxis.set_visible(False) 
# ax.yaxis.set_visible(False) 
# ax.set_frame_on(False) 
# table(ax, transactions,rowLabels=['']*transactions.shape[0],loc='center')
# fig.savefig('./output/transactions.png')

# %% [markdown]
# ### 4. Convert the data types to the appropriate types
#
# (i.e. datetimeindex for the date and float for the amount)

# %%
transactions['date']=pd.to_datetime(transactions['date'])
transactions['amount (USD)'].astype('float')
transactions.set_index('date', inplace=True)
transactions.dtypes
# Out:
# name               object
# amount (USD)      float64
# category           object
# sub category 1     object
# sub category2      object
# dtype: object

# %% [markdown]
# ---

# %% [markdown]
# # Income Analysis with Plaid
#
# In this section, you will use the Plaid Sandbox to complete the following:
# 1. Determine the previous year's gross income and print the results
# 2. Determine the current monthly income and print the results
# 3. Determine the projected yearly income and print the results

# %%
# YOUR CODE HERE
income_response = client.Income.get(access_token)
lst=[['last_year_income_before_tax',income_response['income']['last_year_income_before_tax']],['monthly_income',income_response['income']['income_streams'][0]['monthly_income']],['projected_yearly_income_before_tax',income_response['income']['projected_yearly_income_before_tax']]]
inc=pd.DataFrame(lst)
inc.columns=['Income stream', 'income (USD)']
print(f"The previous year's gross revenues was ${income_response['income']['last_year_income_before_tax']}")
print(f"The monthly revenues are  ${income_response['income']['income_streams'][0]['monthly_income']}")
print(f"The next year's projected gross revenues is ${income_response['income']['projected_yearly_income_before_tax']}")
# fig, ax = plt.subplots(1,1)
# ax.xaxis.set_visible(False)
# ax.yaxis.set_visible(False) 
# ax.set_frame_on(False) 
# table(ax, inc,rowLabels=['']*inc.shape[0],loc='center')
# fig.savefig('./output/inc.png')
# Out:
# The previous year's gross revenues was $7285
# The monthly revenues are  $500
# The next year's projected gross revenues is $7389

# %% [markdown]
# ---

# %% [markdown]
# # Budget Analysis
# In this section, you will use the transactions DataFrame to analyze the customer's budget
#
# 1. Calculate the total spending per category and print the results (Hint: groupby or count transactions per category)
# 2. Generate a bar chart with the number of transactions for each category
# 3. Calculate the expenses per month
# 4. Plot the total expenses per month

# %% [markdown]
# ### Calculate the expenses per category

# %%
transaction_category=transactions.groupby('category').sum()
transaction_category.columns=['amount (USD)']
transaction_category
# fig, ax = plt.subplots(1,1)
# ax.xaxis.set_visible(False) 
# ax.yaxis.set_visible(False) 
# ax.set_frame_on(False) 
# table(ax, transaction_category,loc='center')
# fig.savefig('./output/transactions_by_cat.png')
# Out:
#                 amount (USD)
# category
# Food and Drink       3317.19
# Payment              6310.50
# Recreation            235.50
# Shops                1500.00
# Transfer            20537.34
# Travel                 35.19

# %%
trans_count=transactions['category'].value_counts()
fig_trans_pie=trans_count.plot.pie(y='amount (USD)', figsize=(10,10), title='Transations by count')
fig_trans_pie.figure.savefig('./output/fig_trans_pie.png', bbox_inches='tight', dpi=150)

# %%
fig_trans_bar=transaction_category.plot(kind="bar",figsize=(15,10), title="Expenses by category")
# fig_trans_bar.figure.savefig('./output/fig_trans_bar.jpg', bbox_inches='tight', dpi=150)

# %% [markdown]
# ### Calculate the expenses per month

# %%
transactions_months=transactions.groupby([transactions.index.year, transactions.index.month]).sum()
trans_cat_month=transactions.groupby([transactions.index.year, transactions.index.month, 'category']).sum()
transactions_months.round({'amount (USD)':2})
transactions_months.columns=['Monthy transaction amound (USD)']
trans_cat_month.round({'amount (USD)':2})
trans_cat_month.columns=['Monthy transaction amound (USD)']
trans_cat_month
# fig, ax = plt.subplots(1,1)
# ax.xaxis.set_visible(False) 
# ax.yaxis.set_visible(False) 
# ax.set_frame_on(False) 
# table(ax, trans_cat_month,loc='center')
# fig.savefig('./output/trans_cat_month.png')
# Out:
#                           Monthy transaction amound (USD)
# date date category
# 2020 1    Food and Drink                          1000.00
#           Payment                                 2078.50
#           Shops                                    500.00
#           Travel                                   506.33
#      2    Food and Drink                          1105.73
#           Payment                                 2103.50
#           Recreation                                78.50
#           Shops                                    500.00
#           Transfer                                6845.78
#           Travel                                  -488.27
#      3    Food and Drink                          1105.73
#           Payment                                 2103.50
#           Recreation                                78.50
#           Shops                                    500.00
#           Transfer                                6845.78
#           Travel                                   511.73
#      4    Food and Drink                           105.73
#           Payment                                   25.00
#           Recreation                                78.50
#           Transfer                                6845.78
#           Travel                                  -494.60

# %%
transactions_months
# fig, ax = plt.subplots(1,1)
# ax.xaxis.set_visible(False) 
# ax.yaxis.set_visible(False) 
# ax.set_frame_on(False) 
# table(ax, transactions_months,loc='center')
# fig.savefig('./output/transactions_months.png')
# Out:
#            Monthy transaction amound (USD)
# date date
# 2020 1                             4084.83
#      2                            10145.24
#      3                            11145.24
#      4                             6560.41

# %%
fig_monthly=transactions_months.plot(kind="bar",figsize=(15,10), title="Expenses for last 90 Days")

# fig_monthly.figure.savefig('./output/fig_monthly.jpg', bbox_inches='tight', dpi=150)

# %%
fig=trans_cat_month.plot(kind="bar",figsize=(15,10), title="Expenses for last 90 Days")
fig.figure.savefig('./output/trans_cat_monthly.png', bbox_inches='tight', dpi=150)
